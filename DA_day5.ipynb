# %%
import requests

# %%
page=requests.get('https://randomfox.ca/floof')

# %%
print(page.status_code)
# Out:
# 200

# %%
print(page.text)
# Out:
# {"image":"https:\/\/randomfox.ca\/images\/112.jpg","link":"https:\/\/randomfox.ca\/?i=112"}

# %%
#This example uses Python 2.7 and the python-request library.

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '3697f70c-5a58-4bf5-968d-aade8dac6202',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2024-02-16T09:45:45.639Z', 'error_code': 0, 'error_message': None, 'elapsed': 1, 'credit_count': 1, 'notice': None}, 'data': [{'id': 190, 'name': '2i8ob3zihmh', 'symbol': 'ephcgfxg1xa', 'slug': 'x8x233ej28f', 'cmc_rank': 4487, 'num_market_pairs': 8315, 'circulating_supply': 6136, 'total_supply': 622, 'max_supply': 317, 'infinite_supply': None, 'last_updated': '2024-02-16T09:45:45.639Z', 'date_added': '2024-02-16T09:45:45.639Z', 'tags': ['65vgjxrp7y6', 'd1ss0nsi0x', 'b77hfagmxeq', '2gckqsptlwd', 'xo1dt5kfxa', 'ndad7bn4zsg', '2jfcb7rhtp2', 'sih9qevq0vd', 'hxxtpvtic4', 'uh641syb5f'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.36725520769392794, 'volume_24h': 3688, 'volume_change_24h': 0.6164286870867624, 'percent_change_1h': 0.299354977461479, 'percent_change_24h': 0.47774620872446727, 'percent_change_7d': 0.38925639786112876, 'market_cap': 0.43469076914372784, 'market_cap_dominance
# ...

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd
norm = pd.json_normalize(data['data'])

# %%
norm
# Out:
#      id          name       symbol         slug  cmc_rank  num_market_pairs  \
# 0   190   2i8ob3zihmh  ephcgfxg1xa  x8x233ej28f      4487              8315
# 1  1259  01341nkva2pg  arrphyfi5wp  fqxdpyr3jzw      3043              6062
# 2  4303     mpt2fapd8  bw5ys7354ju  hjk19s9z4gt      6787              4760
# 3   554   gpgknzt2ubb  u80pgdayirg  hwc0rd3u1b8      1201              3978
# 4  5723    lyubj5jil8   zxxokjst9a   uhji95vgf2      8611              8698
# 5  6868   cuaxcfsd2qd  7a5zkkwklrr  75v4lk0994f      2497              8592
# 6  4942    i72yp7tldo  hc2zjkb2dl8   k5m6cfhhug      2757              6393
# 7  3344     nvx327foa   ygjy5rywil  2ja4afir5s8      9791              5318
# 8  3326   1loqiac09mq    a3lahpibj   mg920bu8q1      6388              1085
# 9  5874   kb8fanysxxs   qhxzyba12j  s3cviiq319s      1759              4875
#
#    circulating_supply  total_supply  max_supply infinite_supply  ...  \
# ...

# %% [markdown]
# Problem
#
# Extracting data from CoinMarket cap API:
# - Program Flow:
# - 1.Go to Coinmarket cap wedsite
# - 2.Go to products--> API and obtain API key
# - 3.Go to documents to obtain API code!
# - 4.Know your code!
# - 5.Run it in any python environment
# - 6.Obtain data in the form of json
# - 7.Normalize the data into a dataframe
# - 8.Save it if you needed

# %% [markdown]
# Machine Learning
#
# *   Like humans learn from their past experiences,machines learn from past data!
# *   Training a machine on various things is called Machine Learning.
# *   based on the more chance of the particular case..it will consider
# *  Types:
# 1.Supervised Reinforcement
# 2.Unsupervised Reinforcement
